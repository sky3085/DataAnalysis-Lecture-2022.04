# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
cctv=pd.read_csv('cctv.csv', skiprows=1, encoding='EUC-KR')
cctv.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0    계  83,557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1  종로구   1,715      815    NaN    NaN    195    150      0     261      85
# 2  중 구   2,447       16    114     87     77    236    240     372     386
# 3  용산구   2,611       34     71    234    125    221    298     351     125
# 4  성동구   3,829      163    144    208    107    325    255     967     415
#
#     2019년   2020년  2021년
# 0  12,267  11,247  7,904
# 1       9     200      0
# 2     155     361    403
# 3     307     617    228
# 4     490     472    283

# %%
cctv.isna().sum().sum()#Nan값이 2개 있음
# Out:
# 2

# %%
cctv.fillna(0, inplace=True)
cctv.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0    계  83,557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1  종로구   1,715      815      0      0    195    150      0     261      85
# 2  중 구   2,447       16    114     87     77    236    240     372     386
# 3  용산구   2,611       34     71    234    125    221    298     351     125
# 4  성동구   3,829      163    144    208    107    325    255     967     415
#
#     2019년   2020년  2021년
# 0  12,267  11,247  7,904
# 1       9     200      0
# 2     155     361    403
# 3     307     617    228
# 4     490     472    283

# %%
cctv['총계']=cctv['총계'].str.replace(',','')
cctv.head()
# Out:
#     구분     총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0    계  83557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1  종로구   1715      815      0      0    195    150      0     261      85
# 2  중 구   2447       16    114     87     77    236    240     372     386
# 3  용산구   2611       34     71    234    125    221    298     351     125
# 4  성동구   3829      163    144    208    107    325    255     967     415
#
#     2019년   2020년  2021년
# 0  12,267  11,247  7,904
# 1       9     200      0
# 2     155     361    403
# 3     307     617    228
# 4     490     472    283

# %%
cctv.loc[0]=cctv.loc[0].str.replace(',','')
cctv.head()
# Out:
#     구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년  2017년  2018년  2019년  \
# 0    계  83557     4812  1851  3434  4295  6840  8708  11572  10627  12267
# 1  종로구   1715      815     0     0   195   150     0    261     85      9
# 2  중 구   2447       16   114    87    77   236   240    372    386    155
# 3  용산구   2611       34    71   234   125   221   298    351    125    307
# 4  성동구   3829      163   144   208   107   325   255    967    415    490
#
#    2020년 2021년
# 0  11247  7904
# 1    200     0
# 2    361   403
# 3    617   228
# 4    472   283

# %%
cctv['최근증가율'] = cctv.loc[:, '2012년 이전': '2017년'].astype(float).sum(axis=1) / cctv.loc[:,'2018년': '2020년'].astype(float).sum(axis=1)
cctv.head()
# Out:
#     구분     총계 2012년 이전 2012년 2013년 2014년 2015년 2016년  2017년  2018년  2019년  \
# 0    계  83557     4812  1851  3434  4295  6840  8708  11572  10627  12267
# 1  종로구   1715      815     0     0   195   150     0    261     85      9
# 2  중 구   2447       16   114    87    77   236   240    372    386    155
# 3  용산구   2611       34    71   234   125   221   298    351    125    307
# 4  성동구   3829      163   144   208   107   325   255    967    415    490
#
#    2020년 2021년     최근증가율
# 0  11247  7904  1.215899
# 1    200     0  4.833333
# 2    361   403  1.266075
# 3    617   228  1.271687
# 4    472   283  1.575163

# %%
cctv_new = cctv[['구분', '총계', '최근증가율']]
cctv_new.rename(columns={'구분':'구별', '총계':'cctv댓수'}, inplace=True)
cctv_new.head()
# Out:
#     구별 cctv댓수     최근증가율
# 0    계  83557  1.215899
# 1  종로구   1715  4.833333
# 2  중 구   2447  1.266075
# 3  용산구   2611  1.271687
# 4  성동구   3829  1.575163

# %%
cctv_new['구별'] = cctv_new['구별'].str.replace(' ','')
cctv_new.drop([0], inplace=True)
cctv_new.head()
# Out:
#     구별 cctv댓수     최근증가율
# 1  종로구   1715  4.833333
# 2   중구   2447  1.266075
# 3  용산구   2611  1.271687
# 4  성동구   3829  1.575163
# 5  광진구   3211  0.890533

# %%
person = pd.read_csv('서울시인구.txt', sep='\t', skiprows=2)
person.head()
# Out:
#      기간  자치구         세대          계         남자         여자        계.1  \
# 0  2021   합계  4,426,007  9,736,027  4,721,977  5,014,050  9,509,458
# 1  2021  종로구     73,494    153,789     74,186     79,603    144,683
# 2  2021   중구     63,519    131,787     64,083     67,704    122,499
# 3  2021  용산구    111,036    237,285    115,085    122,200    222,953
# 4  2021  성동구    134,233    292,672    142,259    150,413    285,990
#
#         남자.1       여자.1      계.2     남자.2     여자.2  세대당인구   65세이상고령자
# 0  4,618,040  4,891,418  226,569  103,937  122,632   2.15  1,605,416
# 1     70,183     74,500    9,106    4,003    5,103   1.97     27,818
# 2     59,630     62,869    9,288    4,453    4,835   1.93     24,392
# 3    107,210    115,743   14,332    7,875    6,457   2.01     39,070
# 4    139,380    146,610    6,682    2,879    3,803   2.13     46,380

# %%
person.isna().sum().sum()
# Out:
# 0

# %%
person_new = person[['자치구', '계', '계.1','계.2','65세이상고령자']]
person_new.head()
# Out:
#    자치구          계        계.1      계.2   65세이상고령자
# 0   합계  9,736,027  9,509,458  226,569  1,605,416
# 1  종로구    153,789    144,683    9,106     27,818
# 2   중구    131,787    122,499    9,288     24,392
# 3  용산구    237,285    222,953   14,332     39,070
# 4  성동구    292,672    285,990    6,682     46,380

# %%
person_new['계']=person_new['계'].str.replace(',','')
person_new['계.1']=person_new['계.1'].str.replace(',','')
person_new['계.2']=person_new['계.2'].str.replace(',','')
person_new['65세이상고령자']=person_new['65세이상고령자'].str.replace(',','')
person_new.head()
# Out:
#    자치구        계      계.1     계.2 65세이상고령자
# 0   합계  9736027  9509458  226569  1605416
# 1  종로구   153789   144683    9106    27818
# 2   중구   131787   122499    9288    24392
# 3  용산구   237285   222953   14332    39070
# 4  성동구   292672   285990    6682    46380

# %%
person_new.columns=['구별','인구수','내국인','외국인','노령자']
person_new.head()
# Out:
#     구별      인구수      내국인     외국인      노령자
# 0   합계  9736027  9509458  226569  1605416
# 1  종로구   153789   144683    9106    27818
# 2   중구   131787   122499    9288    24392
# 3  용산구   237285   222953   14332    39070
# 4  성동구   292672   285990    6682    46380

# %%
person_new.drop([0], inplace=True)
person_new.head()
# Out:
#     구별     인구수     내국인    외국인    노령자
# 1  종로구  153789  144683   9106  27818
# 2   중구  131787  122499   9288  24392
# 3  용산구  237285  222953  14332  39070
# 4  성동구  292672  285990   6682  46380
# 5  광진구  352627  339996  12631  51723

# %%
person_new['외국인비율']=person_new['외국인'].astype(float)/person_new['인구수'].astype(float)*100
person_new['노령자비율']=person_new['노령자'].astype(float)/person_new['인구수'].astype(float)*100
person_new.head()
# Out:
#     구별     인구수     내국인    외국인    노령자     외국인비율      노령자비율
# 1  종로구  153789  144683   9106  27818  5.921100  18.088420
# 2   중구  131787  122499   9288  24392  7.047736  18.508654
# 3  용산구  237285  222953  14332  39070  6.039994  16.465432
# 4  성동구  292672  285990   6682  46380  2.283102  15.847092
# 5  광진구  352627  339996  12631  51723  3.581972  14.667907

# %%
answer = pd.merge(cctv_new,person_new,how='inner')
answer.set_index('구별',inplace=True)
answer
# Out:
#      cctv댓수     최근증가율     인구수     내국인    외국인    노령자     외국인비율      노령자비율
# 구별
# 종로구    1715  4.833333  153789  144683   9106  27818  5.921100  18.088420
# 중구     2447  1.266075  131787  122499   9288  24392  7.047736  18.508654
# 용산구    2611  1.271687  237285  222953  14332  39070  6.039994  16.465432
# 성동구    3829  1.575163  292672  285990   6682  46380  2.283102  15.847092
# 광진구    3211  0.890533  352627  339996  12631  51723  3.581972  14.667907
# 동대문구   2628  2.752336  352006  337400  14606  62211  4.149361  17.673278
# 중랑구    3737  0.524803  391885  387350   4535  71682  1.157227  18.291591
# 성북구    4602  1.288986  440142  430528   9614  74709  2.184295  16.973840
# 강북구    3090  0.232941  302563  299182   3381  64333  1.117453  21.262679
# 도봉구    1930  1.170455  319373  317366   2007  64160  0.628419  20.089363
# 노원구    2492  1.460455  514946  510956   3990  88345  0.774839  17.156168
# 은평구    4131  0.848485  477173  473307   3866  87241  0.810188  18.282887
# ...

# %%
answer.to_csv('cctv_pop.csv')
