# %% [markdown]
# ### Pandas - 데이터 조작

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - 탐색을 위한 메소드

# %%
cctv = pd.read_csv('서울시.csv', skiprows=1, encoding='EUC-KR', thousands=',')
cctv
# Out:
#       구분     총계  2012년 이전   2012년   2013년  2014년  2015년  2016년  2017년  2018년  \
# 0      계  83557      4812  1851.0  3434.0   4295   6840   8708  11572  10627
# 1    종로구   1715       815     NaN     NaN    195    150      0    261     85
# 2    중 구   2447        16   114.0    87.0     77    236    240    372    386
# 3    용산구   2611        34    71.0   234.0    125    221    298    351    125
# 4    성동구   3829       163   144.0   208.0    107    325    255    967    415
# 5    광진구   3211        35    57.0   100.0    187     98     52    675    465
# 6   동대문구   2628         4     0.0    14.0     16    115    804    814    201
# 7    중랑구   3737       346    21.0   253.0     72    132    155    153    174
# 8    성북구   4602        81    78.0   170.0    229    322    594    890    867
# 9    강북구   3090         8     0.0    22.0     61    124    251     29    391
# 10   도봉구   1930       128    22.0     2.0    145    172    123    129    222
# ...

# %%
cctv.head(3)
# Out:
#     구분     총계  2012년 이전   2012년   2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  83557      4812  1851.0  3434.0   4295   6840   8708  11572  10627
# 1  종로구   1715       815     NaN     NaN    195    150      0    261     85
# 2  중 구   2447        16   114.0    87.0     77    236    240    372    386
#
#    2019년  2020년  2021년
# 0  12267  11247   7904
# 1      9    200      0
# 2    155    361    403

# %%
cctv.tail(3)
# Out:
#      구분    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 23  강남구  6871        69   67.0   66.0    580    830   1293    988    745
# 24  송파구  2897        40   59.0   90.0     85    214    176    241    541
# 25  강동구  2809       268   27.0  227.0     49    154    202    273    377
#
#     2019년  2020년  2021년
# 23    791    926    516
# 24   1073    235    143
# 25    356    614    262

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        26 non-null     object
#  1   총계        26 non-null     int64
#  2   2012년 이전  26 non-null     int64
#  3   2012년     25 non-null     float64
#  4   2013년     25 non-null     float64
#  5   2014년     26 non-null     int64
#  6   2015년     26 non-null     int64
#  7   2016년     26 non-null     int64
#  8   2017년     26 non-null     int64
#  9   2018년     26 non-null     int64
#  10  2019년     26 non-null     int64
#  11  2020년     26 non-null     int64
#  12  2021년     26 non-null     int64
# dtypes: float64(2), int64(10), object(1)
# memory usage: 2.8+ KB

# %%
cctv.describe()
# Out:
#                  총계     2012년 이전        2012년        2013년        2014년  \
# count     26.000000    26.000000    25.000000    25.000000    26.000000
# mean    6427.461538   370.153846   148.080000   274.720000   330.384615
# std    15771.960982   944.401512   361.187846   666.781169   820.973085
# min     1715.000000     0.000000     0.000000     2.000000    16.000000
# 25%     2524.750000    17.750000    22.000000    66.000000    77.750000
# 50%     3072.500000    61.500000    71.000000   155.000000   124.000000
# 75%     4075.500000   326.500000   122.000000   227.000000   200.250000
# max    83557.000000  4812.000000  1851.000000  3434.000000  4295.000000
#
#              2015년        2016년         2017년         2018년         2019년  \
# count    26.000000    26.000000     26.000000     26.000000     26.000000
# mean    526.153846   669.846154    890.153846    817.461538    943.615385
# std    1299.881062  1661.524233   2197.574912   2012.223511   2330.228368
# ...

# %%
df = pd.DataFrame(np.random.randint(40,101,20).reshape(4,5), columns=list('ABCDE'), index=list('wyxz'))
df
# Out:
#     A   B   C   D   E
# w  93  56  68  76  91
# y  98  93  92  84  43
# x  59  90  76  55  95
# z  48  46  92  84  75

# %%
df.describe()
# Out:
#               A          B     C          D          E
# count   4.00000   4.000000   4.0   4.000000   4.000000
# mean   74.50000  71.250000  82.0  74.750000  76.000000
# std    24.74537  23.767976  12.0  13.696107  23.636131
# min    48.00000  46.000000  68.0  55.000000  43.000000
# 25%    56.25000  53.500000  74.0  70.750000  67.000000
# 50%    76.00000  73.000000  84.0  80.000000  83.000000
# 75%    94.25000  90.750000  92.0  84.000000  92.000000
# max    98.00000  93.000000  92.0  84.000000  95.000000

# %% [markdown]
# - 통계 : sum mean min max std quantile

# %%
df.sum()#열단위 axis=0
# Out:
# A    298
# B    285
# C    328
# D    299
# E    304
# dtype: int64

# %%
df.std()
# Out:
# A    24.745370
# B    23.767976
# C    12.000000
# D    13.696107
# E    23.636131
# dtype: float64

# %%
df.quantile(0.25, axis=1)
# Out:
# w    68.0
# y    84.0
# x    59.0
# z    48.0
# Name: 0.25, dtype: float64

# %% [markdown]
# - 결측치 처리

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.isna().sum()#열단위로 값이 계산
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.isna().sum().sum()
# Out:
# 869

# %%
#age 결측치는 평균으로 대체
titanic.age.fillna(titanic.age.mean(), inplace=True)
titanic.tail()
# Out:
#      survived  pclass     sex        age  sibsp  parch   fare embarked  \
# 886         0       2    male  27.000000      0      0  13.00        S
# 887         1       1  female  19.000000      0      0  30.00        S
# 888         0       3  female  29.699118      1      2  23.45        S
# 889         1       1    male  26.000000      0      0  30.00        C
# 890         0       3    male  32.000000      0      0   7.75        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True

# %%
# embarked 는 최빈값으로 대체
titanic.embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
titanic.embarked.fillna('S', inplace=True)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
# embark_town결측치는 행 삭제
titanic.dropna(subset=['embark_town'], inplace=True)
titanic.shape
# Out:
# (889, 15)

# %%
titanic.drop(columns=['deck'], inplace=True)
titanic.shape
# Out:
# (889, 14)

# %%
df
# Out:
#     A   B   C   D   E
# w  93  56  68  76  91
# y  98  93  92  84  43
# x  59  90  76  55  95
# z  48  46  92  84  75

# %%
# 각 열의 최대값과 최소값의 차이
df.apply(lambda x : x.max()-x.min())
# Out:
# A    50
# B    47
# C    24
# D    29
# E    52
# dtype: int64

# %%
# 각 행의 최대값과 최소값의 차이
df.apply(lambda x : x.max() - x.min(), axis=1)
# Out:
# w    37
# y    55
# x    40
# z    46
# dtype: int64

# %%
titanic['adult/child']=titanic.age.apply(lambda x: 'adult' if x>20 else 'child')
titanic.tail()
# Out:
#      survived  pclass     sex        age  sibsp  parch   fare embarked  \
# 886         0       2    male  27.000000      0      0  13.00        S
# 887         1       1  female  19.000000      0      0  30.00        S
# 888         0       3  female  29.699118      1      2  23.45        S
# 889         1       1    male  26.000000      0      0  30.00        C
# 890         0       3    male  32.000000      0      0   7.75        Q
#
#       class    who  adult_male  embark_town alive  alone adult/child
# 886  Second    man        True  Southampton    no   True       adult
# 887   First  woman       False  Southampton   yes   True       child
# 888   Third  woman       False  Southampton    no  False       adult
# 889   First    man        True    Cherbourg   yes   True       adult
# 890   Third    man        True   Queenstown    no   True       adult

# %%
cctv.head()
# Out:
#     구분     총계  2012년 이전   2012년   2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  83557      4812  1851.0  3434.0   4295   6840   8708  11572  10627
# 1  종로구   1715       815     NaN     NaN    195    150      0    261     85
# 2  중 구   2447        16   114.0    87.0     77    236    240    372    386
# 3  용산구   2611        34    71.0   234.0    125    221    298    351    125
# 4  성동구   3829       163   144.0   208.0    107    325    255    967    415
#
#    2019년  2020년  2021년
# 0  12267  11247   7904
# 1      9    200      0
# 2    155    361    403
# 3    307    617    228
# 4    490    472    283

# %%
# 이미 강사님과 다르게 정수형으로 되어 있음
# 천단위 , 를 삭제하고 정수형으로 바꾸는 방법
#cctv['총계']=cctv['총계'].apply(lambda x : int(x.replace(',','')))

# %%
cctv.isna().sum()
# Out:
# 구분          0
# 총계          0
# 2012년 이전    0
# 2012년       1
# 2013년       1
# 2014년       0
# 2015년       0
# 2016년       0
# 2017년       0
# 2018년       0
# 2019년       0
# 2020년       0
# 2021년       0
# dtype: int64

# %%
cctv['2012년'].fillna(0, inplace=True)
cctv['2013년'].fillna(0, inplace=True)
cctv.head()
# Out:
#     구분     총계  2012년 이전   2012년   2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    계  83557      4812  1851.0  3434.0   4295   6840   8708  11572  10627
# 1  종로구   1715       815     0.0     0.0    195    150      0    261     85
# 2  중 구   2447        16   114.0    87.0     77    236    240    372    386
# 3  용산구   2611        34    71.0   234.0    125    221    298    351    125
# 4  성동구   3829       163   144.0   208.0    107    325    255    967    415
#
#    2019년  2020년  2021년
# 0  12267  11247   7904
# 1      9    200      0
# 2    155    361    403
# 3    307    617    228
# 4    490    472    283

# %%
cctv.columns
# Out:
# Index(['구분', '총계', '2012년 이전', '2012년', '2013년', '2014년', '2015년', '2016년',
#        '2017년', '2018년', '2019년', '2020년', '2021년'],
#       dtype='object')

# %%
# 이미 정수형이므로 에러
# 반복문을 이용한 천단위 ,를 정수형으로 변환하기
#for col in cctv.columns[2:]:
#   cctv[col] = cctv[col].apply(lambda x: int(x.replace(',','')))
