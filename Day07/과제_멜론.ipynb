# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import requests

# %%
url = 'https://www.melon.com/chart/index.htm'
header={'User-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.88 Safari/537.36'}
req = requests.get(url, headers=header)
soup = BeautifulSoup(req.text, 'html.parser')
lis = soup.select('tr.lst50')
#print(lis)
#len(lis)
lines=[]
for li in lis:
    title = li.select_one('.ellipsis.rank01 a').get_text()
    artist = li.select_one('.ellipsis.rank02 > a').get_text()
    rank = li.select_one('span.rank').get_text()
    album = li.select_one('.ellipsis.rank03 > a').get_text()
    #print(title, rank, album)
    lines.append([rank, title, artist, album])
df = pd.DataFrame(lines, columns=['rank', 'title', 'artist', 'album'])
df.to_csv('MelonTop100.csv', index=False)
answer=pd.read_csv('MelonTop100.csv')
answer
# Out:
#     rank                                   title             artist  \
# 0      1                    봄여름가을겨울 (Still Life)       BIGBANG (빅뱅)
# 1      2                                  TOMBOY            (여자)아이들
# 2      3                               LOVE DIVE          IVE (아이브)
# 3      4                          Feel My Rhythm  Red Velvet (레드벨벳)
# 4      5                                  사랑인가 봐               멜로망스
# 5      6                    GANADARA (Feat. 아이유)                박재범
# 6      7                               사랑은 늘 도망가                임영웅
# 7      8                                    취중고백         김민석 (멜로망스)
# 8      9                                    INVU       태연 (TAEYEON)
# 9     10                                  듣고 싶을까      MSG워너비(M.O.M)
# 10    11                                  ELEVEN          IVE (아이브)
# 11    12                           다정히 내 이름을 부르면               경서예지
# 12    13                                   RUN2U        STAYC(스테이씨)
# ...

# %%
url = 'https://www.melon.com/chart/day/index.htm'
header={'User-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.88 Safari/537.36'}
req = requests.get(url, headers=header)
soup = BeautifulSoup(req.text, 'html.parser')
lis = soup.select('tr.lst50')
#print(lis)
#len(lis)
lines=[]
for li in lis:
    title = li.select_one('.ellipsis.rank01 a').get_text()
    artist = li.select_one('.ellipsis.rank02 > a').get_text()
    rank = li.select_one('span.rank').get_text()
    album = li.select_one('.ellipsis.rank03 > a').get_text()
    #print(title, rank, album)
    lines.append([rank, title, artist, album])
df = pd.DataFrame(lines, columns=['rank', 'title', 'artist', 'album'])
df.to_csv('MelonDay.csv', index=False)
answer=pd.read_csv('MelonDay.csv')
answer
# Out:
#     rank                                   title             artist  \
# 0      1                    봄여름가을겨울 (Still Life)       BIGBANG (빅뱅)
# 1      2                                  TOMBOY            (여자)아이들
# 2      3                               LOVE DIVE          IVE (아이브)
# 3      4                          Feel My Rhythm  Red Velvet (레드벨벳)
# 4      5                                  사랑인가 봐               멜로망스
# 5      6                    GANADARA (Feat. 아이유)                박재범
# 6      7                                    취중고백         김민석 (멜로망스)
# 7      8                                    INVU       태연 (TAEYEON)
# 8      9                                  듣고 싶을까      MSG워너비(M.O.M)
# 9     10                               사랑은 늘 도망가                임영웅
# 10    11                                  ELEVEN          IVE (아이브)
# 11    12                           다정히 내 이름을 부르면               경서예지
# 12    13                                   RUN2U        STAYC(스테이씨)
# ...
